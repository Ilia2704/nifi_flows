# %% [markdown]
# ### Использование NiFi API и библиотеки Python NiPyAPI для управления потоком данных

# %% [markdown]
# #### 1. Установка необходимых библиотек

# %% [raw]
# pip install nipyapi
# pip install --upgrade nipyapi
# pip install --upgrade paramiko

# %% [markdown]
# #### 2. Импорт библиотеки взаимодействия с NiFi через API и присваивание хоста и порта

# %%
"https://nipyapi.readthedocs.io/en/latest/index.html"
"https://github.com/Chaffelson/nipyapi/tree/main/nipyapi"

import nipyapi

# %%
nipyapi.config.nifi_config.host = 'http://10.129.0.54:8443/nifi-api' # put your nifi host here

# %% [markdown]
# #### 3. Установка соединения и запрос на получение списка процессоров

# %%
#Команда отмены проверки сертификатов 
nipyapi.config.nifi_config.ssl_ca_cert = False

#Команда получения корневой процесс группы
root_pg = nipyapi.canvas.get_root_pg_id()

#Команда получания списка процессоров из корневой процесс группы
processors = nipyapi.canvas.list_all_processors(root_pg)

#Вывод списка процессоров - имя и ID
for processor in processors:
    print(f"Processor Name: {processor.component.name}, Processor ID: {processor.id}")

print(f"Корневой процесс {root_pg}")
# Out:
# Processor Name: MergeRecord, Processor ID: e3a0fc2c-d8fe-371e-62e1-551a5fe20b84
# Processor Name: AttributesToJSON, Processor ID: 13081c36-5f86-3cc4-f6f4-5427b60f326c
# Processor Name: Re-Merge, Processor ID: 002fedd7-1834-3efb-7cbc-3eda1bf43e55
# Processor Name: SplitRecord, Processor ID: 32dfd48c-c427-38ba-991c-f5e7e8cc65b8
# Processor Name: AttributesToCSV, Processor ID: 9ec3d95a-4358-3c7e-77bd-ca32dbb81717
# Processor Name: JoinEnrichment, Processor ID: 3c12312e-3fa5-32b1-735a-4daf2323158f
# Processor Name: GetFile, Processor ID: 75af742d-cab8-380a-d618-6a3cc3b3d679
# Processor Name: FlattenJson, Processor ID: 829d0c85-69a0-3b62-cbb1-3661e663b227
# Processor Name: ExecuteSQL, Processor ID: eb4e6916-1775-35a9-7097-7b9a712737db
# Processor Name: MergeContent, Processor ID: f94b8768-84fe-31d7-aea6-08cf538afa04
# Processor Name: GenerateFlowFile, Processor ID: 595da082-2077-38a1-dd83-602883880cb3
# Processor Name: InvokeHTTP, Processor ID: 7ffa9e82-2305-3a95-0645-f2a59bab1023
# Processor Name: PutFile, Processor ID: 8bfa5517-424e-38c7-5788-c0d3d48f71f3
# Processor Name: UpdateAttribute, Processor ID: 39faed07-8908-3011-8bee-1540510db0e3
# Processor Name: GenerateFlowFile, Processor ID: 3397d035-0199-1000-a975-4dbdc1cb52a2
# Processor Name: UpdateAttribute_Day+1, Processor ID: 07af6172-669e-3cae-1a27-069e3ca5c60b
# Processor Name: ReplaceText, Processor ID: d2f6d2b1-fc23-31e7-fce4-d970a2f981be
# Processor Name: RouteOnContent, Processor ID: e46f6c10-2a99-3ce2-2db5-949512e07297
# Processor Name: MergeRecord, Processor ID: 38ae6164-0199-1000-9061-0bbfa9486b31
# Processor Name: HandleHttpRequest, Processor ID: 2138f021-8406-33f2-7165-ee8c863674fc
# Processor Name: GenerateFlowFile, Processor ID: e633af45-b984-32fa-7d0b-dd0662f09c43
# Processor Name: ListFile, Processor ID: e97f43e5-91ba-3e17-b090-ae7c6903c22d
# Processor Name: Write to '/processed2', Processor ID: fc85c9f3-075e-3e15-106b-1c63edeb40cc
# Processor Name: UpdateAttribute, Processor ID: 339807fa-0199-1000-2498-c265a1f47106
# Processor Name: JoltTransformJSON, Processor ID: 64ac558e-6b75-315f-0385-03b3641a8451
# Processor Name: UpdateAttribute, Processor ID: 25e2a433-1776-3aa2-1bc1-e536d8e315fd
# Processor Name: 1 Line per FlowFile, Processor ID: d2a01835-a401-3321-35af-e56e65507ebf
# Processor Name: QueryRecord, Processor ID: c70a587d-184e-342e-f2ab-9532980bb467
# Processor Name: ListFile, Processor ID: 0750c333-9a73-35fa-d46f-6ccc9f18792a
# Processor Name: ConvertRecord, Processor ID: 508a4692-e3ef-3230-1aa0-a944fb706d2c
# Processor Name: Add process_time, Write as JSON, Processor ID: fcae6739-1fc7-3724-fa7e-fbd0c69e137d
# Processor Name: Add process_timestamp, Processor ID: 4d726a74-5180-34b7-3c01-05bbd3c40b1d
# Processor Name: RouteOnAttribute, Processor ID: abe21d9b-6dd6-3d1c-7e9c-df1bde1d5d93
# Processor Name: LogAttribute, Processor ID: 5f6f6840-b4c2-3ad2-0fc4-7f7235516092
# Processor Name: LookupRecord, Processor ID: 578eaa22-6cf5-3b97-fc8a-eef2f45f355c
# Processor Name: InvokeHTTP, Processor ID: b10de027-8074-3090-7523-cbc63f9e567b
# Processor Name: JoinEnrichment, Processor ID: 33a07a35-9425-34fd-5f41-0b8a7cdb929a
# Processor Name: GenerateFlowFile, Processor ID: 231bc7f1-8841-372f-889b-8399322a0d89
# Processor Name: SplitJson, Processor ID: 1f0e8d23-ceca-30f6-3a48-47e88193b39a
# Processor Name: JoltTransformJSON, Processor ID: 1ea32c35-a88f-3e9d-26c2-3fa52e933b6e
# Processor Name: FetchFile, Processor ID: 9d1c602d-0033-3a3b-e1c9-15d1f9f9dea0
# Processor Name: SplitToJsons, Processor ID: 3cfeb060-a8b6-3495-4d53-70e1f5afc54b
# Processor Name: JoltTransformJSON, Processor ID: fe2c5073-b4ce-3ae1-1c60-46680c8892cc
# Processor Name: GenerateFlowFile, Processor ID: 19f75d7d-0eb5-3c56-ef18-10d1e3b8c021
# Processor Name: Check if Needs Reporting, Processor ID: a68a40cc-6da8-3bb7-b890-17598d802810
# Processor Name: CountText, Processor ID: 5146a229-4255-38cd-21f9-86eb905e3d5c
# Processor Name: UpdateAttribute, Processor ID: 8a5061c0-ce1b-3fb8-760c-c54f64008def
# Processor Name: Extract Key Values, Processor ID: 75fb9556-292a-3e9c-518c-b4cc04bfe2f4
# Processor Name: UpdateRecord, Processor ID: 34719caa-930a-344e-3fc8-0d6a2424130a
# Processor Name: PutFile, Processor ID: 42f48a05-c0fd-3663-65d0-c3bddd4f710d
# Processor Name: HandleHttpResponse, Processor ID: 6897976c-9961-3ef9-0022-7bb58ce49533
# Processor Name: MergeRecord, Processor ID: a0d36546-b894-392d-39b7-ba70de1f1e7c
# Processor Name: ForkEnrichment, Processor ID: f28f016d-3466-304a-9a42-6d6a10c35497
# Processor Name: FetchFile, Processor ID: 39357051-058b-3317-8957-157cd3b3de6f
# Processor Name: PutDatabaseRecord, Processor ID: d4dc2e04-71ed-31b9-db75-aaa9cdbb36c6
# Processor Name: UnpackContent, Processor ID: 1ca26185-b405-369b-7d2c-15ffe45b04e5
# Processor Name: PutFile, Processor ID: 33992ac2-0199-1000-eb04-573ef48c39cc
# Processor Name: ConvertRecord, Processor ID: 37901146-dee5-3194-542f-7a5b05953f0a
# Processor Name: EvaluateJsonPath, Processor ID: 48b42a4b-9927-311d-841b-ea78e78b0cab
# Processor Name: RouteOnAttribute, Processor ID: 33aa85d8-961a-33f0-9d7f-1a5a02141a1d
# Processor Name: EvaluateJsonPath, Processor ID: 6a1765be-e61a-3c2f-fd9c-3fd830649c35
# Processor Name: Write to '/processed', Processor ID: 8e0fd1a2-d261-3018-1b22-47eea831094c
# Processor Name: UpdateAttribute, Processor ID: d6972acc-15c6-39d6-819a-a05f5c8f4d8f
# Processor Name: RouteToDate, Processor ID: 7471fdce-bf3b-3550-07b2-20bc13eb627c
# Processor Name: InvokeHTTP, Processor ID: e491b3c8-93a3-3dfe-c748-98a8d4b01efd
# Processor Name: MergeContent, Processor ID: ebc7f434-f14e-39bc-eb07-62d09116b0d0
# Processor Name: UpdateAttribute, Processor ID: 4c789bfc-3a67-30db-a775-5e89b5bf40ba
# Processor Name: Check if Needs Reporting, Processor ID: 95828a74-f981-3fc3-3b6e-5768909aeb3b
# Processor Name: QueryDatabaseTableRecord, Processor ID: 2812e15c-0631-3019-57fe-83bf8eda7da8
# Processor Name: GenerateFlowFile, Processor ID: d9fb283f-6789-3ddd-cdc4-c94af210546d
# Processor Name: QueryRecord, Processor ID: 38adea01-0199-1000-6e55-aa0347904ffb
# Корневой процесс 33699316-0199-1000-14fc-27edac8e126e

# %% [markdown]
# #### 4. Запуск и остановка процессора по его имени

# %%
# Запуск процессора по имени с кучей дополнений
processor_name = 'StartFromAPI'
processors = nipyapi.canvas.list_all_processors()
processor_entity = None
for proc in processors:
    if proc.component.name == processor_name:
        processor_entity = proc
        break

if processor_entity:
    # Запуск процессора
    switcher = False # True - запуск процессора и False - остановка
    nipyapi.canvas.schedule_processor(processor_entity, switcher)  
    print(f"Процессор {processor_name} сейчас запущен - {switcher}")
else:
    print(f"Процессор {processor_name} не найден.")
# Out:
# Процессор StartFromAPI сейчас запущен - False

# %%
# Однократный запуск процессора (RunOnce)
import time
import nipyapi

# Укажите имя процессора
processor_name = 'StartFromAPI'

# Получение списка всех процессоров
processors = nipyapi.canvas.list_all_processors()
processor_entity = None

# Поиск процессора по имени
for proc in processors:
    if proc.component.name == processor_name:
        processor_entity = proc
        break

if processor_entity:
    # Запуск процессора
    nipyapi.canvas.schedule_processor(processor_entity, True)
    print(f"Процессор {processor_name} запущен")

    # Проверка состояния процессора и ожидание завершения работы
    while processor_entity.status.aggregate_snapshot.active_thread_count > 0:
        time.sleep(1)
        processor_entity = nipyapi.canvas.get_processor(processor_entity.id, 'id')

    # Остановка процессора
    nipyapi.canvas.schedule_processor(processor_entity, False)
    print(f"Процессор {processor_name} остановлен")
else:
    print(f"Процессор {processor_name} не найден.")
# Out:
# Процессор StartFromAPI запущен
# Процессор StartFromAPI остановлен

# %% [markdown]
# #### 5. Изменить атрибут процессора по его ID
# - Список всех атрибутов объекта canvas

# %%
import nipyapi

# Print all attributes and methods of the canvas module
print(dir(nipyapi.canvas))
# Out:
# ['__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', '_raise', 'absolute_import', 'create_connection', 'create_controller', 'create_funnel', 'create_port', 'create_process_group', 'create_processor', 'create_remote_process_group', 'delete_connection', 'delete_controller', 'delete_funnel', 'delete_port', 'delete_process_group', 'delete_processor', 'delete_remote_process_group', 'exception_handler', 'get_bulletin_board', 'get_bulletins', 'get_component_connections', 'get_controller', 'get_controller_type', 'get_flow', 'get_funnel', 'get_pg_parents_ids', 'get_process_group', 'get_process_group_status', 'get_processor', 'get_processor_type', 'get_remote_process_group', 'get_root_pg_id', 'get_variable_registry', 'list_all_by_kind', 'list_all_connections', 'list_all_controller_types', 'list_all_controllers', 'list_all_funnels', 'list_all_input_ports', 'list_all_output_ports', 'list_all_process_groups', 'list_all_processor_types', 'list_all_processors', 'list_all_remote_process_groups', 'list_invalid_processors', 'list_sensitive_processors', 'log', 'logging', 'nipyapi', 'purge_connection', 'purge_process_group', 'recurse_flow', 'schedule_components', 'schedule_controller', 'schedule_process_group', 'schedule_processor', 'set_remote_process_group_transmission', 'six', 'update_controller', 'update_process_group', 'update_processor', 'update_variable_registry']

# %% [markdown]
# #### 6. Информация о текущем потоке

# %%
from nipyapi import canvas, config

# Set up the NiFi connection
config.nifi_config.host = 'https://10.129.0.54:8443/nifi-api'

print(canvas.get_flow())
# Out:
# {'permissions': {'can_read': True, 'can_write': True},
#  'process_group_flow': {'breadcrumb': {'breadcrumb': {'id': '33699316-0199-1000-14fc-27edac8e126e',
#                                                       'name': 'NiFi Flow',
#                                                       'version_control_information': None},
#                                        'id': '33699316-0199-1000-14fc-27edac8e126e',
#                                        'parent_breadcrumb': None,
#                                        'permissions': {'can_read': True,
#                                                        'can_write': True},
#                                        'versioned_flow_state': None},
#                         'flow': {'connections': [{'bends': [],
#                                                   'bulletins': None,
#                                                   'component': {'available_relationships': ['success'],
#                                                                 'back_pressure_data_size_threshold': '1 '
#                                                                                                      'GB',
#                                                                 'back_pressure_object_threshold': 10000,
#                                                                 'bends': [],
#                                                                 'destination': {'comments': '',
#                                                                                 'exists': None,
#                                                                                 'group_id': '33699316-0199-1000-14fc-27edac8e126e',
#                                                                                 'id': '3df2cf47-0199-1000-660d-0e5e4fa33da7',
#                                                                                 'name': 'Funnel',
#                                                                                 'running': True,
#                                                                                 'transmitting': None,
#                                                                                 'type': 'FUNNEL',
#                                                                                 'versioned_component_id': 'f3c9aea9-0b30-3044-8d06-559d32604f68'},
#                                                                 'flow_file_expiration': '0 '
#                                                                                         'sec',
#                                                                 'getz_index': None,
#                                                                 'id': '3e198f63-0199-1000-48a9-eb451c6203f5',
#                                                                 'label_index': 0,
#                                                                 'load_balance_compression': 'DO_NOT_COMPRESS',
#                                                                 'load_balance_partition_attribute': '',
#                                                                 'load_balance_status': 'LOAD_BALANCE_NOT_CONFIGURED',
#                                                                 'load_balance_strategy': 'DO_NOT_LOAD_BALANCE',
#                                                                 'name': '',
#                                                                 'parent_group_id': '33699316-0199-1000-14fc-27edac8e126e',
#                                                                 'position': None,
#                                                                 'prioritizers': [],
#                                                                 'selected_relationships': ['success'],
#                                                                 'source': {'comments': '',
#                                                                            'exists': None,
#                                                                            'group_id': '33699316-0199-1000-14fc-27edac8e126e',
#                                                                            'id': '3e196e9d-0199-1000-4fc4-de7a2a6b6f7a',
#                                                                            'name': 'StartFromAPI',
#                                                                            'running': False,
#                                                                            'transmitting': None,
#                                                                            'type': 'PROCESSOR',
#                                                                            'versioned_component_id': None},
#                                                                 'versioned_component_id': None},
#                                                   'destination_group_id': '33699316-0199-1000-14fc-27edac8e126e',
#                                                   'destination_id': '3df2cf47-0199-1000-660d-0e5e4fa33da7',
#                                                   'destination_type': 'FUNNEL',
#                                                   'disconnected_node_acknowledged': None,
#                                                   'getz_index': None,
#                                                   'id': '3e198f63-0199-1000-48a9-eb451c6203f5',
#                                                   'label_index': 0,
#                                                   'permissions': {'can_read': True,
#                                                                   'can_write': True},
#                                                   'position': None,
#                                                   'revision': {'client_id': '3d2378a2-1197-4485-ae2b-a845b7322b11',
#                                                                'last_modifier': None,
#                                                                'version': 1},
#                                                   'source_group_id': '33699316-0199-1000-14fc-27edac8e126e',
#                                                   'source_id': '3e196e9d-0199-1000-4fc4-de7a2a6b6f7a',
#                                                   'source_type': 'PROCESSOR',
#                                                   'status': {'aggregate_snapshot': {'bytes_in': 0,
#                                                                                     'bytes_out': 0,
#                                                                                     'bytes_queued': 0,
#                                                                                     'destination_id': None,
#                                                                                     'destination_name': 'Funnel',
#                                                                                     'flow_file_availability': 'FLOWFILE_AVAILABLE',
#                                                                                     'flow_files_in': 24,
#                                                                                     'flow_files_out': 0,
#                                                                                     'flow_files_queued': 2,
#                                                                                     'group_id': '33699316-0199-1000-14fc-27edac8e126e',
#                                                                                     'id': '3e198f63-0199-1000-48a9-eb451c6203f5',
#                                                                                     'input': '24 '
#                                                                                              '(0 '
#                                                                                              'bytes)',
#                                                                                     'name': 'success',
#                                                                                     'output': '0 '
#                                                                                               '(0 '
#                                                                                               'bytes)',
#                                                                                     'percent_use_bytes': 0,
#                                                                                     'percent_use_count': 0,
#                                                                                     'predictions': None,
#                                                                                     'queued': '2 '
#                                                                                               '(0 '
#                                                                                               'bytes)',
#                                                                                     'queued_count': '2',
#                                                                                     'queued_size': '0 '
#                                                                                                    'bytes',
#                                                                                     'source_id': None,
#                                                                                     'source_name': 'StartFromAPI'},
#                                                              'destination_id': '3df2cf47-0199-1000-660d-0e5e4fa33da7',
#                                                              'destination_name': 'Funnel',
#                                                              'group_id': '33699316-0199-1000-14fc-27edac8e126e',
#                                                              'id': '3e198f63-0199-1000-48a9-eb451c6203f5',
#                                                              'name': 'success',
#                                                              'node_snapshots': None,
#                                                              'source_id': '3e196e9d-0199-1000-4fc4-de7a2a6b6f7a',
#                                                              'source_name': 'StartFromAPI',
#                                                              'stats_last_refreshed': '13:28:07 '
#                                                                                      'UTC'},
#                                                   'uri': 'http://10.129.0.54:8443/nifi-api/connections/3e198f63-0199-1000-48a9-eb451c6203f5'},
#                                                  {'bends': [],
#                                                   'bulletins': None,
#                                                   'component': {'available_relationships': None,
#                                                                 'back_pressure_data_size_threshold': '1 '
#                                                                                                      'GB',
#                                                                 'back_pressure_object_threshold': 10000,
#                                                                 'bends': [],
#                                                                 'destination': {'comments': '',
#                                                                                 'exists': None,
#                                                                                 'group_id': '33699316-0199-1000-14fc-27edac8e126e',
#                                                                                 'id': '3df2cf47-0199-1000-660d-0e5e4fa33da7',
#                                                                                 'name': 'Funnel',
#                                                                                 'running': True,
#                                                                                 'transmitting': None,
#                                                                                 'type': 'FUNNEL',
#                                                                                 'versioned_component_id': 'f3c9aea9-0b30-3044-8d06-559d32604f68'},
#                                                                 'flow_file_expiration': '0 '
#                                                                                         'sec',
#                                                                 'getz_index': None,
#                                                                 'id': '3df2dfc8-0199-1000-942f-ce9398f9198d',
#                                                                 'label_index': 0,
#                                                                 'load_balance_compression': 'DO_NOT_COMPRESS',
#                                                                 'load_balance_partition_attribute': '',
#                                                                 'load_balance_status': 'LOAD_BALANCE_NOT_CONFIGURED',
#                                                                 'load_balance_strategy': 'DO_NOT_LOAD_BALANCE',
#                                                                 'name': '',
#                                                                 'parent_group_id': '33699316-0199-1000-14fc-27edac8e126e',
#                                                                 'position': None,
#                                                                 'prioritizers': [],
#                                                                 'selected_relationships': None,
#                                                                 'source': {'comments': None,
#                                                                            'exists': None,
#                                                                            'group_id': '33699316-0199-1000-14fc-27edac8e126e',
#                                                                            'id': '3deb55d5-0199-1000-2575-7be3143c3632',
#                                                                            'name': 'input_from_remote',
#                                                                            'running': True,
#                                                                            'transmitting': None,
#                                                                            'type': 'INPUT_PORT',
#                                                                            'versioned_component_id': '07a0e9f0-f69d-3876-a83c-12c6672c28c1'},
#                                                                 'versioned_component_id': '435b4e5b-4fb1-3a1f-9a48-92437521d031'},
#                                                   'destination_group_id': '33699316-0199-1000-14fc-27edac8e126e',
#                                                   'destination_id': '3df2cf47-0199-1000-660d-0e5e4fa33da7',
#                                                   'destination_type': 'FUNNEL',
#                                                   'disconnected_node_acknowledged': None,
#                                                   'getz_index': None,
#                                                   'id': '3df2dfc8-0199-1000-942f-ce9398f9198d',
#                                                   'label_index': 0,
#                                                   'permissions': {'can_read': True,
#                                                                   'can_write': True},
#                                                   'position': None,
#                                                   'revision': {'client_id': None,
#                                                                'last_modifier': None,
#                                                                'version': 0},
#                                                   'source_group_id': '33699316-0199-1000-14fc-27edac8e126e',
#                                                   'source_id': '3deb55d5-0199-1000-2575-7be3143c3632',
#                                                   'source_type': 'INPUT_PORT',
#                                                   'status': {'aggregate_snapshot': {'bytes_in': 0,
#                                                                                     'bytes_out': 0,
#                                                                                     'bytes_queued': 1555,
#                                                                                     'destination_id': None,
#                                                                                     'destination_name': 'Funnel',
#                                                                                     'flow_file_availability': 'FLOWFILE_AVAILABLE',
#                                                                                     'flow_files_in': 0,
#                                                                                     'flow_files_out': 0,
#                                                                                     'flow_files_queued': 17,
#                                                                                     'group_id': '33699316-0199-1000-14fc-27edac8e126e',
#                                                                                     'id': '3df2dfc8-0199-1000-942f-ce9398f9198d',
#                                                                                     'input': '0 '
#                                                                                              '(0 '
#                                                                                              'bytes)',
#                                                                                     'name': '',
#                                                                                     'output': '0 '
#                                                                                               '(0 '
#                                                                                               'bytes)',
#                                                                                     'percent_use_bytes': 0,
#                                                                                     'percent_use_count': 0,
#                                                                                     'predictions': None,
#                                                                                     'queued': '17 '
#                                                                                               '(1.52 '
#                                                                                               'KB)',
#                                                                                     'queued_count': '17',
#                                                                                     'queued_size': '1.52 '
#                                                                                                    'KB',
#                                                                                     'source_id': None,
#                                                                                     'source_name': 'input_from_remote'},
#                                                              'destination_id': '3df2cf47-0199-1000-660d-0e5e4fa33da7',
#                                                              'destination_name': 'Funnel',
#                                                              'group_id': '33699316-0199-1000-14fc-27edac8e126e',
#                                                              'id': '3df2dfc8-0199-1000-942f-ce9398f9198d',
#                                                              'name': '',
#                                                              'node_snapshots': None,
#                                                              'source_id': '3deb55d5-0199-1000-2575-7be3143c3632',
#                                                              'source_name': 'input_from_remote',
#                                                              'stats_last_refreshed': '13:28:07 '
#                                                                                      'UTC'},
#                                                   'uri': 'http://10.129.0.54:8443/nifi-api/connections/3df2dfc8-0199-1000-942f-ce9398f9198d'}],
#                                  'funnels': [{'bulletins': None,
#                                               'component': {'id': '3df2cf47-0199-1000-660d-0e5e4fa33da7',
#                                                             'parent_group_id': '33699316-0199-1000-14fc-27edac8e126e',
#                                                             'position': {'x': 8.0,
#                                                                          'y': -392.0},
#                                                             'versioned_component_id': 'f3c9aea9-0b30-3044-8d06-559d32604f68'},
#                                               'disconnected_node_acknowledged': None,
#                                               'id': '3df2cf47-0199-1000-660d-0e5e4fa33da7',
#                                               'permissions': {'can_read': True,
#                                                               'can_write': True},
#                                               'position': {'x': 8.0,
#                                                            'y': -392.0},
#                                               'revision': {'client_id': None,
#                                                            'last_modifier': None,
#                                                            'version': 0},
#                                               'uri': 'http://10.129.0.54:8443/nifi-api/funnels/3df2cf47-0199-1000-660d-0e5e4fa33da7'}],
#                                  'input_ports': [{'allow_remote_access': True,
#                                                   'bulletins': [],
#                                                   'component': {'allow_remote_access': True,
#                                                                 'comments': None,
#                                                                 'concurrently_schedulable_task_count': 1,
#                                                                 'group_access_control': None,
#                                                                 'id': '3deb55d5-0199-1000-2575-7be3143c3632',
#                                                                 'name': 'input_from_remote',
#                                                                 'parent_group_id': '33699316-0199-1000-14fc-27edac8e126e',
#                                                                 'position': {'x': -584.0,
#                                                                              'y': -408.0},
#                                                                 'state': 'RUNNING',
#                                                                 'transmitting': False,
#                                                                 'type': 'INPUT_PORT',
#                                                                 'user_access_control': None,
#                                                                 'validation_errors': None,
#                                                                 'versioned_component_id': '07a0e9f0-f69d-3876-a83c-12c6672c28c1'},
#                                                   'disconnected_node_acknowledged': None,
#                                                   'id': '3deb55d5-0199-1000-2575-7be3143c3632',
#                                                   'operate_permissions': {'can_read': True,
#                                                                           'can_write': True},
#                                                   'permissions': {'can_read': True,
#                                                                   'can_write': True},
#                                                   'port_type': 'INPUT_PORT',
#                                                   'position': {'x': -584.0,
#                                                                'y': -408.0},
#                                                   'revision': {'client_id': '3d2378a2-1197-4485-ae2b-a845b7322b11',
#                                                                'last_modifier': None,
#                                                                'version': 1},
#                                                   'status': {'aggregate_snapshot': {'active_thread_count': 1,
#                                                                                     'bytes_in': 0,
#                                                                                     'bytes_out': 0,
#                                                                                     'flow_files_in': 0,
#                                                                                     'flow_files_out': 0,
#                                                                                     'group_id': '33699316-0199-1000-14fc-27edac8e126e',
#                                                                                     'id': '3deb55d5-0199-1000-2575-7be3143c3632',
#                                                                                     'input': '0 '
#                                                                                              '(0 '
#                                                                                              'bytes)',
#                                                                                     'name': 'input_from_remote',
#                                                                                     'output': '0 '
#                                                                                               '(0 '
#                                                                                               'bytes)',
#                                                                                     'run_status': 'Running',
#                                                                                     'transmitting': None},
#                                                              'group_id': '33699316-0199-1000-14fc-27edac8e126e',
#                                                              'id': '3deb55d5-0199-1000-2575-7be3143c3632',
#                                                              'name': 'input_from_remote',
#                                                              'node_snapshots': None,
#                                                              'run_status': 'Running',
#                                                              'stats_last_refreshed': '13:28:07 '
#                                                                                      'UTC',
#                                                              'transmitting': False},
#                                                   'uri': 'http://10.129.0.54:8443/nifi-api/input-ports/3deb55d5-0199-1000-2575-7be3143c3632'}],
#                                  'labels': [],
#                                  'output_ports': [],
#                                  'process_groups': [{'active_remote_port_count': 0,
#                                                      'bulletins': [],
#                                                      'component': {'active_remote_port_count': 0,
#                                                                    'comments': '',
#                                                                    'contents': None,
#                                                                    'default_back_pressure_data_size_threshold': '1 '
#                                                                                                                 'GB',
#                                                                    'default_back_pressure_object_threshold': 10000,
#                                                                    'default_flow_file_expiration': '0 '
#                                                                                                    'sec',
#                                                                    'disabled_count': 0,
#                                                                    'flowfile_concurrency': 'UNBOUNDED',
#                                                                    'flowfile_outbound_policy': 'STREAM_WHEN_AVAILABLE',
#                                                                    'id': '3395bcdf-0199-1000-1e56-321aef33f32c',
#                                                                    'inactive_remote_port_count': 0,
#                                                                    'input_port_count': 0,
#                                                                    'invalid_count': 0,
#                                                                    'local_input_port_count': 0,
#                                                                    'local_output_port_count': 0,
#                                                                    'locally_modified_and_stale_count': 0,
#                                                                    'locally_modified_count': 0,
#                                                                    'log_file_suffix': None,
#                                                                    'name': 'lab_1',
#                                                                    'output_port_count': 0,
#                                                                    'parameter_context': None,
#                                                                    'parent_group_id': '33699316-0199-1000-14fc-27edac8e126e',
#                                                                    'position': {'x': 232.0,
#                                                                                 'y': -240.0},
#                                                                    'public_input_port_count': 0,
#                                                                    'public_output_port_count': 0,
#                                                                    'running_count': 1,
#                                                                    'stale_count': 0,
#                                                                    'stopped_count': 5,
#                                                                    'sync_failure_count': 0,
#                                                                    'up_to_date_count': 0,
#                                                                    'variables': None,
#                                                                    'version_control_information': {'bucket_id': 'c48cf61e-e672-405d-a223-55852275c222',
#                                                                                                    'bucket_name': 'bucket_nifi_course',
#                                                                                                    'flow_description': '',
#                                                                                                    'flow_id': 'c95c7dec-3634-4155-a713-80ca3a5af6d2',
#                                                                                                    'flow_name': 'first_example',
#                                                                                                    'group_id': '3395bcdf-0199-1000-1e56-321aef33f32c',
#                                                                                                    'registry_id': '33c66ad7-0199-1000-6e4b-62c1f3bde5d8',
#                                                                                                    'registry_name': 'NifiRegistryFlow_example',
#                                                                                                    'state': 'STALE',
#                                                                                                    'state_explanation': 'A '
#                                                                                                                         'newer '
#                                                                                                                         'version '
#                                                                                                                         'of '
#                                                                                                                         'this '
#                                                                                                                         'flow '
#                                                                                                                         'is '
#                                                                                                                         'available',
#                                                                                                    'storage_location': 'http://10.129.0.54:18080/nifi-registry-api/buckets/c48cf61e-e672-405d-a223-55852275c222/flows/c95c7dec-3634-4155-a713-80ca3a5af6d2/versions/3',
#                                                                                                    'version': 2},
#                                                                    'versioned_component_id': '095ab14e-e558-33fb-9483-922feaf443d5'},
#                                                      'disabled_count': 0,
#                                                      'disconnected_node_acknowledged': None,
#                                                      'id': '3395bcdf-0199-1000-1e56-321aef33f32c',
#                                                      'inactive_remote_port_count': 0,
#                                                      'input_port_count': 0,
#                                                      'invalid_count': 0,
#                                                      'local_input_port_count': 0,
#                                                      'local_output_port_count': 0,
#                                                      'locally_modified_and_stale_count': 0,
#                                                      'locally_modified_count': 0,
#                                                      'output_port_count': 0,
#                                                      'parameter_context': None,
#                                                      'permissions': {'can_read': True,
#                                                                      'can_write': True},
#                                                      'position': {'x': 232.0,
#                                                                   'y': -240.0},
#                                                      'process_group_update_strategy': None,
#                                                      'public_input_port_count': 0,
#                                                      'public_output_port_count': 0,
#                                                      'revision': {'client_id': None,
#                                                                   'last_modifier': None,
#                                                                   'version': 0},
#                                                      'running_count': 1,
#                                                      'stale_count': 0,
#                                                      'status': {'aggregate_snapshot': {'active_thread_count': 0,
#                                                                                        'bytes_in': 0,
#                                                                                        'bytes_out': 0,
#                                                                                        'bytes_queued': 178,
#                                                                                        'bytes_read': 0,
#                                                                                        'bytes_received': 0,
#                                                                                        'bytes_sent': 0,
#                                                                                        'bytes_transferred': 0,
#                                                                                        'bytes_written': 0,
#                                                                                        'connection_status_snapshots': None,
#                                                                                        'flow_files_in': 0,
#                                                                                        'flow_files_out': 0,
#                                                                                        'flow_files_queued': 3,
#                                                                                        'flow_files_received': 0,
#                                                                                        'flow_files_sent': 0,
#                                                                                        'flow_files_transferred': 0,
#                                                                                        'id': '3395bcdf-0199-1000-1e56-321aef33f32c',
#                                                                                        'input': '0 '
#                                                                                                 '(0 '
#                                                                                                 'bytes)',
#                                                                                        'input_port_status_snapshots': None,
#                                                                                        'name': 'lab_1',
#                                                                                        'output': '0 '
#                                                                                                  '(0 '
#                                                                                                  'bytes)',
#                                                                                        'output_port_status_snapshots': None,
#                                                                                        'process_group_status_snapshots': None,
#                                                                                        'processing_nanos': 0,
#                                                                                        'processor_status_snapshots': None,
#                                                                                        'queued': '3 '
#                                                                                                  '(178 '
#                                                                                                  'bytes)',
#                                                                                        'queued_count': '3',
#                                                                                        'queued_size': '178 '
#                                                                                                       'bytes',
#                                                                                        'read': '0 '
#                                                                                                'bytes',
#                                                                                        'received': '0 '
#                                                                                                    '(0 '
#                                                                                                    'bytes)',
#                                                                                        'remote_process_group_status_snapshots': None,
#                                                                                        'sent': '0 '
#                                                                                                '(0 '
#                                                                                                'bytes)',
#                                                                                        'terminated_thread_count': 0,
#                                                                                        'transferred': '0 '
#                                                                                                       '(0 '
#                                                                                                       'bytes)',
#                                                                                        'versioned_flow_state': 'STALE',
#                                                                                        'written': '0 '
#                                                                                                   'bytes'},
#                                                                 'id': '3395bcdf-0199-1000-1e56-321aef33f32c',
#                                                                 'name': 'lab_1',
#                                                                 'node_snapshots': None,
#                                                                 'stats_last_refreshed': '13:28:07 '
#                                                                                         'UTC'},
#                                                      'stopped_count': 5,
#                                                      'sync_failure_count': 0,
#                                                      'up_to_date_count': 0,
#                                                      'uri': 'http://10.129.0.54:8443/nifi-api/process-groups/3395bcdf-0199-1000-1e56-321aef33f32c',
#                                                      'versioned_flow_snapshot': None,
#                                                      'versioned_flow_state': 'STALE'},
#                                                     {'active_remote_port_count': 0,
#                                                      'bulletins': [],
#                                                      'component': {'active_remote_port_count': 0,
#                                                                    'comments': '',
#                                                                    'contents': None,
#                                                                    'default_back_pressure_data_size_threshold': '1 '
#                                                                                                                 'GB',
#                                                                    'default_back_pressure_object_threshold': 10000,
#                                                                    'default_flow_file_expiration': '0 '
#                                                                                                    'sec',
#                                                                    'disabled_count': 0,
#                                                                    'flowfile_concurrency': 'UNBOUNDED',
#                                                                    'flowfile_outbound_policy': 'STREAM_WHEN_AVAILABLE',
#                                                                    'id': '38d2d949-0199-1000-d70f-eb9b769f27ff',
#                                                                    'inactive_remote_port_count': 0,
#                                                                    'input_port_count': 0,
#                                                                    'invalid_count': 0,
#                                                                    'local_input_port_count': 0,
#                                                                    'local_output_port_count': 0,
#                                                                    'locally_modified_and_stale_count': 0,
#                                                                    'locally_modified_count': 0,
#                                                                    'log_file_suffix': None,
#                                                                    'name': 'Process_Group_Feature',
#                                                                    'output_port_count': 0,
#                                                                    'parameter_context': None,
#                                                                    'parent_group_id': '33699316-0199-1000-14fc-27edac8e126e',
#                                                                    'position': {'x': 760.0,
#                                                                                 'y': -240.0},
#                                                                    'public_input_port_count': 0,
#                                                                    'public_output_port_count': 0,
#                                                                    'running_count': 4,
#                                                                    'stale_count': 0,
#                                                                    'stopped_count': 10,
#                                                                    'sync_failure_count': 0,
#                                                                    'up_to_date_count': 0,
#                                                                    'variables': None,
#                                                                    'version_control_information': {'bucket_id': 'c48cf61e-e672-405d-a223-55852275c222',
#                                                                                                    'bucket_name': 'bucket_nifi_course',
#                                                                                                    'flow_description': '',
#                                                                                                    'flow_id': '8fc1c6b0-8456-4f96-b1e8-5dedf462dcd3',
#                                                                                                    'flow_name': 'DEMO_PG',
#                                                                                                    'group_id': '38d2d949-0199-1000-d70f-eb9b769f27ff',
#                                                                                                    'registry_id': '33c66ad7-0199-1000-6e4b-62c1f3bde5d8',
#                                                                                                    'registry_name': 'NifiRegistryFlow_example',
#                                                                                                    'state': 'UP_TO_DATE',
#                                                                                                    'state_explanation': 'Flow '
#                                                                                                                         'version '
#                                                                                                                         'is '
#                                                                                                                         'current',
#                                                                                                    'storage_location': 'http://10.129.0.54:18080/nifi-registry-api/buckets/c48cf61e-e672-405d-a223-55852275c222/flows/8fc1c6b0-8456-4f96-b1e8-5dedf462dcd3/versions/2',
#                                                                                                    'version': 2},
#                                                                    'versioned_component_id': '5c4fa07c-38c2-365c-8e84-91196807f1e0'},
#                                                      'disabled_count': 0,
#                                                      'disconnected_node_acknowledged': None,
#                                                      'id': '38d2d949-0199-1000-d70f-eb9b769f27ff',
#                                                      'inactive_remote_port_count': 0,
#                                                      'input_port_count': 0,
# ...
#                                                                                                                       'display_name': 'Custom '
#                                                                                                                                       'Text',
#                                                                                                                       'dynamic': False,
#                                                                                                                       'expression_language_scope': 'Environment '
#                                                                                                                                                    'variables '
#                                                                                                                                                    'defined '
#                                                                                                                                                    'at '
#                                                                                                                                                    'JVM '
#                                                                                                                                                    'level '
#                                                                                                                                                    'and '
#                                                                                                                                                    'system '
#                                                                                                                                                    'properties',
#                                                                                                                       'identifies_controller_service': None,
#                                                                                                                       'identifies_controller_service_bundle': None,
#                                                                                                                       'name': 'generate-ff-custom-text',
#                                                                                                                       'required': False,
#                                                                                                                       'sensitive': False,
#                                                                                                                       'supports_el': True},
#                                                                                           'mime-type': {'allowable_values': None,
#                                                                                                         'default_value': None,
#                                                                                                         'dependencies': [],
#                                                                                                         'description': 'Specifies '
#                                                                                                                        'the '
#                                                                                                                        'value '
#                                                                                                                        'to '
#                                                                                                                        'set '
#                                                                                                                        'for '
#                                                                                                                        'the '
#                                                                                                                        '"mime.type" '
#                                                                                                                        'attribute.',
#                                                                                                         'display_name': 'Mime '
#                                                                                                                         'Type',
#                                                                                                         'dynamic': False,
#                                                                                                         'expression_language_scope': 'Not '
#                                                                                                                                      'Supported',
#                                                                                                         'identifies_controller_service': None,
#                                                                                                         'identifies_controller_service_bundle': None,
#                                                                                                         'name': 'mime-type',
#                                                                                                         'required': False,
#                                                                                                         'sensitive': False,
#                                                                                                         'supports_el': False}},
#                                                                           'execution_node': 'ALL',
#                                                                           'loss_tolerant': False,
#                                                                           'max_backoff_period': '10 '
#                                                                                                 'mins',
#                                                                           'penalty_duration': '30 '
#                                                                                               'sec',
#                                                                           'properties': {'Batch Size': '1',
#                                                                                          'Data Format': 'Text',
#                                                                                          'File Size': '0B',
#                                                                                          'Unique FlowFiles': 'false',
#                                                                                          'character-set': 'UTF-8',
#                                                                                          'generate-ff-custom-text': None,
#                                                                                          'mime-type': None},
#                                                                           'retried_relationships': [],
#                                                                           'retry_count': 10,
#                                                                           'run_duration_millis': 0,
#                                                                           'scheduling_period': '2 '
#                                                                                                'sec',
#                                                                           'scheduling_strategy': 'TIMER_DRIVEN',
#                                                                           'sensitive_dynamic_property_names': None,
#                                                                           'yield_duration': '1 '
#                                                                                             'sec'},
#                                                                'deprecated': False,
#                                                                'description': None,
#                                                                'execution_node_restricted': False,
#                                                                'extension_missing': False,
#                                                                'id': '3e196e9d-0199-1000-4fc4-de7a2a6b6f7a',
#                                                                'input_requirement': 'INPUT_FORBIDDEN',
#                                                                'multiple_versions_available': False,
#                                                                'name': 'StartFromAPI',
#                                                                'parent_group_id': '33699316-0199-1000-14fc-27edac8e126e',
#                                                                'persists_state': False,
#                                                                'position': {'x': -144.0,
#                                                                             'y': -672.0},
#                                                                'relationships': [{'auto_terminate': False,
#                                                                                   'description': '',
#                                                                                   'name': 'success',
#                                                                                   'retry': False}],
#                                                                'restricted': False,
#                                                                'state': 'STOPPED',
#                                                                'style': {},
#                                                                'supports_batching': True,
#                                                                'supports_event_driven': None,
#                                                                'supports_parallel_processing': True,
#                                                                'supports_sensitive_dynamic_properties': False,
#                                                                'type': 'org.apache.nifi.processors.standard.GenerateFlowFile',
#                                                                'validation_errors': None,
#                                                                'validation_status': 'VALID',
#                                                                'versioned_component_id': None},
#                                                  'disconnected_node_acknowledged': None,
#                                                  'id': '3e196e9d-0199-1000-4fc4-de7a2a6b6f7a',
#                                                  'input_requirement': 'INPUT_FORBIDDEN',
#                                                  'operate_permissions': {'can_read': True,
#                                                                          'can_write': True},
#                                                  'permissions': {'can_read': True,
#                                                                  'can_write': True},
#                                                  'position': {'x': -144.0,
#                                                               'y': -672.0},
#                                                  'revision': {'client_id': '3d2378a2-1197-4485-ae2b-a845b7322b11',
#                                                               'last_modifier': None,
#                                                               'version': 9},
#                                                  'status': {'aggregate_snapshot': {'active_thread_count': 0,
#                                                                                    'bytes_in': 0,
#                                                                                    'bytes_out': 0,
#                                                                                    'bytes_read': 0,
#                                                                                    'bytes_written': 0,
#                                                                                    'execution_node': 'ALL',
#                                                                                    'flow_files_in': 0,
#                                                                                    'flow_files_out': 24,
#                                                                                    'group_id': '33699316-0199-1000-14fc-27edac8e126e',
#                                                                                    'id': '3e196e9d-0199-1000-4fc4-de7a2a6b6f7a',
#                                                                                    'input': '0 '
#                                                                                             '(0 '
#                                                                                             'bytes)',
#                                                                                    'name': 'StartFromAPI',
#                                                                                    'output': '24 '
#                                                                                              '(0 '
#                                                                                              'bytes)',
#                                                                                    'read': '0 '
#                                                                                            'bytes',
#                                                                                    'run_status': 'Stopped',
#                                                                                    'task_count': 24,
#                                                                                    'tasks': '24',
#                                                                                    'tasks_duration': '00:00:00.014',
#                                                                                    'tasks_duration_nanos': 14622993,
#                                                                                    'terminated_thread_count': 0,
#                                                                                    'type': 'GenerateFlowFile',
#                                                                                    'written': '0 '
#                                                                                               'bytes'},
#                                                             'group_id': '33699316-0199-1000-14fc-27edac8e126e',
#                                                             'id': '3e196e9d-0199-1000-4fc4-de7a2a6b6f7a',
#                                                             'name': 'StartFromAPI',
#                                                             'node_snapshots': None,
#                                                             'run_status': 'Stopped',
#                                                             'stats_last_refreshed': '13:28:07 '
#                                                                                     'UTC',
#                                                             'type': None},
#                                                  'uri': 'http://10.129.0.54:8443/nifi-api/processors/3e196e9d-0199-1000-4fc4-de7a2a6b6f7a'}],
#                                  'remote_process_groups': []},
#                         'id': '33699316-0199-1000-14fc-27edac8e126e',
#                         'last_refreshed': '13:28:07 UTC',
#                         'parameter_context': None,
#                         'parent_group_id': None,
#                         'uri': 'http://10.129.0.54:8443/nifi-api/flow/process-groups/33699316-0199-1000-14fc-27edac8e126e'}}

# %% [markdown]
# #### 7. Справочная информация

# %%
import pydoc

# Получение справочной информации о модуле canvas
pydoc.help('nipyapi.canvas')
# Out:
# Help on module nipyapi.canvas in nipyapi:
#
# NAME
#     nipyapi.canvas - For interactions with the NiFi Canvas.
#
# FUNCTIONS
#     create_connection(source, target, relationships=None, name=None)
#         Creates a connection between two objects for the given relationships
#
#         Args:
#             source: Object to initiate the connection, e.g. ProcessorEntity
#             target: Object to terminate the connection, e.g. FunnelEntity
#             relationships (list): list of strings of relationships to connect, may
#                 be collected from the object 'relationships' property (optional)
#             name (str): Defaults to None, String of Name for Connection (optional)
#
#         Returns:
#             (ConnectionEntity): for the created connection
#
#     create_controller(parent_pg, controller, name=None)
#         Creates a new Controller Service in a given Process Group of the given
#             Controller type, with the given Name
#
#         Args:
#             parent_pg (ProcessGroupEntity): Target Parent PG
#             controller (DocumentedTypeDTO): Type of Controller to create, found
#                 via the list_all_controller_types method
#             name (str[Optional]): Name for the new Controller as a String
#
#         Returns:
#             (ControllerServiceEntity)
#
#     create_funnel(pg_id, position=None)
#         Creates a Funnel Object
#
#         Args:
#             pg_id (str): ID of the parent Process Group
#             position (tuple[int, int]): Position on canvas
#
#         Returns:
#             (FunnelEntity) Created Funnel
#
#     create_port(pg_id, port_type, name, state, position=None)
#         Creates a new input or output port of given characteristics
#
#         Args:
#             pg_id (str): ID of the parent Process Group
#             port_type (str): Either of INPUT_PORT or OUTPUT_PORT
#             name (str): optional, Name to assign to the port
#             state (str): One of RUNNING, STOPPED, DISABLED
#             position (tuple): optional, tuple of ints like (400, 400)
#
#         Returns:
#             (PortEntity) of the created port
#
#     create_process_group(parent_pg, new_pg_name, location, comment='')
#         Creates a new Process Group with the given name under the provided parent
#         Process Group at the given Location
#
#         Args:
#             parent_pg (ProcessGroupEntity): The parent Process Group to create the
#                 new process group in
#             new_pg_name (str): The name of the new Process Group
#             location (tuple[x, y]): the x,y coordinates to place the new Process
#                 Group under the parent
#             comment (str): Entry for the Comments field
#
#         Returns:
#              (ProcessGroupEntity): The new Process Group
#
#     create_processor(parent_pg, processor, location, name=None, config=None)
#         Instantiates a given processor on the canvas
#
#         Args:
#             parent_pg (ProcessGroupEntity): The parent Process Group
#             processor (DocumentedTypeDTO): The abstract processor type object to be
#                 instantiated
#             location (tuple[x, y]): The location coordinates
#             name (Optional [str]):  The name for the new Processor
#             config (Optional [ProcessorConfigDTO]): A configuration object for the
#                 new processor
#
#         Returns:
#              (ProcessorEntity): The new Processor
#
#     create_remote_process_group(
#         target_uris,
#         transport='RAW',
#         pg_id='root',
#         position=None
#     )
#         Creates a new Remote Process Group with given parameters
#
#         Args:
#             target_uris (str): Comma separated list of target URIs
#             transport (str): optional, RAW or HTTP
#             pg_id (str): optional, UUID of parent Process Group for remote
#               process group
#             position (tuple): optional, tuple of location ints
#
#         Returns:
#             (RemoteProcessGroupEntity)
#
#     delete_connection(connection, purge=False)
#         Deletes a connection, optionally purges it first
#
#         Args:
#             connection (ConnectionEntity): Connection to delete
#             purge (bool): True to Purge, Defaults to False
#
#         Returns:
#             (ConnectionEntity): the modified Connection
#
#     delete_controller(controller, force=False)
#         Delete a Controller service, with optional prejudice
#
#         Args:
#             controller (ControllerServiceEntity): Target Controller to delete
#             force (bool): True to attempt Disable the Controller before deletion
#
#         Returns:
#             (ControllerServiceEntity)
#
#     delete_funnel(funnel, refresh=True)
#         Deletes a Funnel Object
#
#         Args:
#             funnel (FunnelEntity): The Funnel to delete
#             refresh (bool): Whether to refresh the object state
#                 before execution
#
#         Returns:
#             (FunnelEntity) Deleted FunnelEntity reference
#
#     delete_port(port)
#         Deletes a given port from the canvas if possible
#
#     delete_process_group(process_group, force=False, refresh=True)
#         Deletes a given Process Group, with optional prejudice.
#
#         Args:
#             process_group (ProcessGroupEntity): The target Process Group
#             force (bool): Stop, purge and clean the target Process Group before
#                 deletion. Experimental.
#             refresh (bool): Whether to refresh the state first
#
#         Returns:
#              (ProcessGroupEntity: The updated object state
#
#     delete_processor(processor, refresh=True, force=False)
#         Deletes a Processor from the canvas, with optional prejudice.
#
#         Args:
#             processor (ProcessorEntity): The processor to delete
#             refresh (bool): Whether to refresh the Processor state before action
#             force (bool): Whether to stop, purge and remove connections to the
#                 Processor before deletion. Behavior may change in future releases.
#
#         Returns:
#              (ProcessorEntity): The updated ProcessorEntity
#
#     delete_remote_process_group(rpg, refresh=True)
#         Deletes a given remote process group
#
#         Args:
#             rpg (RemoteProcessGroupEntity): Remote Process Group to remove
#             refresh (bool): Whether to refresh the object before action
#
#         Returns:
#             (RemoteProcessGroupEntity)
#
#     get_bulletin_board()
#         Retrieves the bulletin board object
#
#         Returns:
#             (BulletinBoardEntity): The native datatype BulletinBoard object
#
#     get_bulletins()
#         Retrieves current bulletins (alerts) from the Flow Canvas
#
#         Returns:
#             (ControllerBulletinsEntity): The native datatype containing a list
#         of bulletins
#
#     get_component_connections(component)
#         Returns list of Connections related to a given Component, e.g. Processor
#
#         Args:
#             component: Component Object to filter by, e.g. a ProcessorEntity
#
#         Returns:
#             (list): List of ConnectionEntity Objects
#
#     get_controller(identifier, identifier_type='name', bool_response=False)
#         Retrieve a given Controller
#
#         Args:
#             identifier (str): ID or Name of a Controller to find
#             identifier_type (str): 'id' or 'name', defaults to name
#             bool_response (bool): If True, will return False if the Controller is
#                 not found - useful when testing for deletion completion
#
#         Returns:
#
#     get_flow(pg_id='root')
#         Returns information about a Process Group and flow.
#
#         This surfaces the native implementation, for the recursed implementation
#         see 'recurse_flow'
#
#         Args:
#             pg_id (str): id of the Process Group to retrieve, defaults to the root
#                 process group if not set
#
#         Returns:
#              (ProcessGroupFlowEntity): The Process Group object
#
#     get_funnel(funnel_id)
#         Gets a given Funnel by ID
#
#     get_pg_parents_ids(pg_id)
#         Retrieve the ids of the parent Process Groups.
#
#         Args:
#             pg_id (str): Process group id
#
#         Returns:
#             (list) List of ids of the input PG parents
#
#     get_process_group(identifier, identifier_type='name', greedy=True)
#         Filters the list of all process groups against a given identifier string
#         occurring in a given identifier_type field.
#
#         Args:
#             identifier (str): the string to filter the list for
#             identifier_type (str): the field to filter on, set in config.py
#             greedy (bool): True for partial match, False for exact match
#
#         Returns:
#             None for no matches, Single Object for unique match,
#             list(Objects) for multiple matches
#
#     get_process_group_status(pg_id='root', detail='names')
#         Returns an entity containing the status of the Process Group.
#         Optionally may be configured to return a simple dict of name:id pairings
#
#         Note that there is also a 'process group status' command available, but it
#         returns a subset of this data anyway, and this call is more useful
#
#         Args:
#             pg_id (str): The UUID of the Process Group
#             detail (str): 'names' or 'all'; whether to return a simple dict of
#                 name:id pairings, or the full details. Defaults to 'names'
#
#         Returns:
#              (ProcessGroupEntity): The Process Group Entity including the status
#
#     get_processor(identifier, identifier_type='name', greedy=True)
#         Filters the list of all Processors against the given identifier string in
#         the given identifier_type field
#
#         Args:
#             identifier (str): The String to filter against
#             identifier_type (str): The field to apply the filter to. Set in
#                 config.py
#             greedy (bool): Whether to exact match (False) or partial match (True)
#
#         Returns:
#             None for no matches, Single Object for unique match,
#             list(Objects) for multiple matches
#
#     get_processor_type(identifier, identifier_type='name', greedy=True)
#         Gets the abstract object describing a Processor, or list thereof
#
#         Args:
#             identifier (str): the string to filter the list for
#             identifier_type (str): the field to filter on, set in config.py
#             greedy (bool): False for exact match, True for greedy match
#
#         Returns:
#             None for no matches, Single Object for unique match,
#             list(Objects) for multiple matches
#
#     get_remote_process_group(rpg_id, summary=False)
#         Fetch a remote process group object, with optional summary of just ports
#
#     get_root_pg_id()
#         Convenience function to return the UUID of the Root Process Group
#
#         Returns (str): The UUID of the root PG
#
#     get_variable_registry(process_group, ancestors=True)
#         Gets the contents of the variable registry attached to a Process Group
#
#         Args:
#             process_group (ProcessGroupEntity): The Process Group to retrieve the
#                 Variable Registry from
#             ancestors (bool): Whether to include the Variable Registries from child
#                 Process Groups
#
#         Returns:
#             (VariableRegistryEntity): The Variable Registry
#
#     list_all_by_kind(kind, pg_id='root', descendants=True)
#         Retrieves a list of all instances of a supported object type
#
#         Args:
#             kind (str):  one of input_ports, output_ports, funnels, controllers,
#                 connections, remote_process_groups
#             pg_id (str): optional, ID of the Process Group to use as search base
#             descendants (bool): optional, whether to collect child group info
#
#         Returns:
#             list of the Entity type of the kind, or single instance, or None
#
#     list_all_connections(pg_id='root', descendants=True)
#         Lists all connections for a given Process Group ID
#
#         Args:
#             pg_id (str): ID of the Process Group to retrieve Connections from
#             descendants (bool): True to recurse child PGs, False to not
#
#         Returns:
#             (list): List of ConnectionEntity objects
#
#     list_all_controller_types()
#         Lists all Controller Service types available on the environment
#
#         Returns:
#             list(DocumentedTypeDTO)
#
#     list_all_controllers(pg_id='root', descendants=True)
#         Lists all controllers under a given Process Group, defaults to Root
#             Optionally recurses all child Process Groups as well
#         Args:
#             pg_id (str): String of the ID of the Process Group to list from
#             descendants (bool): True to recurse child PGs, False to not
#
#         Returns:
#             None, ControllerServiceEntity, or list(ControllerServiceEntity)
#
#     list_all_funnels(pg_id='root', descendants=True)
#         Convenience wrapper for list_all_by_kind for funnels
#
#     list_all_input_ports(pg_id='root', descendants=True)
#         Convenience wrapper for list_all_by_kind for input ports
#
#     list_all_output_ports(pg_id='root', descendants=True)
#         Convenience wrapper for list_all_by_kind for output ports
#
#     list_all_process_groups(pg_id='root')
#         Returns a flattened list of all Process Groups on the canvas.
#         Potentially slow if you have a large canvas.
#
#         Note that the ProcessGroupsApi().get_process_groups(pg_id) command only
#         provides the first layer of pgs, whereas this trawls the entire canvas
#
#         Args:
#             pg_id (str): The UUID of the Process Group to start from, defaults to
#                 the Canvas root
#
#         Returns:
#              list[ProcessGroupEntity]
#
#     list_all_processor_types()
#         Produces the list of all available processor types in the NiFi instance
#
#         Returns:
#              list(ProcessorTypesEntity): A native datatype containing the
#              processors list
#
#     list_all_processors(pg_id='root')
#         Returns a flat list of all Processors under the provided Process Group
#
#         Args:
#             pg_id (str): The UUID of the Process Group to start from, defaults to
#                 the Canvas root
#
#         Returns:
#              list[ProcessorEntity]
#
#     list_all_remote_process_groups(pg_id='root', descendants=True)
#         Convenience wrapper for list_all_by_kind for remote process groups
#
#     list_invalid_processors(pg_id='root', summary=False)
#         Returns a flattened list of all Processors with Invalid Statuses
#
#         Args:
#             pg_id (str): The UUID of the Process Group to start from, defaults to
#                 the Canvas root
#             summary (bool): True to return just the list of relevant
#                 properties per Processor, False for the full listing
#
#         Returns:
#             list[ProcessorEntity]
#
#     list_sensitive_processors(pg_id='root', summary=False)
#         Returns a flattened list of all Processors on the canvas which have
#         sensitive properties that would need to be managed during deployment
#
#         Args:
#             pg_id (str): The UUID of the Process Group to start from, defaults to
#                 the Canvas root
#             summary (bool): True to return just the list of relevant
#                 properties per Processor, False for the full listing
#
#         Returns:
#             list[ProcessorEntity] or list(dict)
#
#     purge_connection(con_id)
#         EXPERIMENTAL
#         Drops all FlowFiles in a given connection. Waits until the action is
#         complete before returning.
#
#         Note that if upstream component isn't stopped, more data may flow into
#         the connection after this action.
#
#         Args:
#             con_id (str): The UUID of the Connection to be purged
#
#         Returns:
#             (DropRequestEntity): The status reporting object for the drop
#             request.
#
#     purge_process_group(process_group, stop=False)
#         EXPERIMENTAL
#         Purges the connections in a given Process Group of FlowFiles, and
#         optionally stops it first
#
#         Args:
#             process_group (ProcessGroupEntity): Target Process Group
#             stop (Optional [bool]): Whether to stop the Process Group before action
#
#         Returns:
#             (list[dict{ID:True|False}]): Result set. A list of Dicts of
#         Connection IDs mapped to True or False for success of each connection
#
#     recurse_flow(pg_id='root')
#         Returns information about a Process Group and all its Child Flows.
#         Recurses the child flows by appending each process group with a
#         'nipyapi_extended' parameter which contains the child process groups, etc.
#         Note: This previously used actual recursion which broke on large NiFi
#             environments, we now use a task/list update approach
#
#         Args:
#             pg_id (str): The Process Group UUID
#
#         Returns:
#              (ProcessGroupFlowEntity): enriched NiFi Flow object
#
#     schedule_components(pg_id, scheduled, components=None)
#         Changes the scheduled target state of a list of components within a given
#         Process Group.
#
#         Note that this does not guarantee that components will be Started or
#         Stopped afterwards, merely that they will have their scheduling updated.
#
#         Args:
#             pg_id (str): The UUID of the parent Process Group
#             scheduled (bool): True to start, False to stop
#             components (list[ComponentType]): The list of Component Entities to
#                 schdule, e.g. ProcessorEntity's
#
#         Returns:
#              (bool): True for success, False for not
#
#     schedule_controller(controller, scheduled, refresh=False)
#         Start/Enable or Stop/Disable a Controller Service
#
#         Args:
#             controller (ControllerServiceEntity): Target Controller to schedule
#             scheduled (bool): True to start, False to stop
#             refresh (bool): Whether to refresh the component revision before
#               execution
#
#         Returns:
#             (ControllerServiceEntity)
#
#     schedule_process_group(process_group_id, scheduled)
#         Start or Stop a Process Group and all components.
#
#         Note that this doesn't guarantee that all components have started, as
#         some may be in Invalid states.
#
#         Args:
#             process_group_id (str): The UUID of the target Process Group
#             scheduled (bool): True to start, False to stop
#
#         Returns:
#              (bool): True of successfully scheduled, False if not
#
#     schedule_processor(processor, scheduled, refresh=True)
#         Set a Processor to Start or Stop.
#
#         Note that this doesn't guarantee that it will change state, merely that
#         it will be instructed to try.
#         Some effort is made to wait and see if the processor starts
#
#         Args:
#             processor (ProcessorEntity): The Processor to target
#             scheduled (bool): True to start, False to stop
#             refresh (bool): Whether to refresh the object before action
#
#         Returns:
#             (bool): True for success, False for failure
#
#     set_remote_process_group_transmission(rpg, enable=True, refresh=True)
#         Enable or Disable Transmission for an RPG
#
#         Args:
#             rpg (RemoteProcessGroupEntity): The ID of the remote process group
#               to modify
#             enable (bool): True to enable, False to disable
#             refresh (bool): Whether to refresh the object before action
#
#         Returns:
#
#     update_controller(controller, update)
#         Updates the Configuration of a Controller Service
#
#         Args:
#             controller (ControllerServiceEntity): Target Controller to update
#             update (ControllerServiceDTO): Controller Service configuration object
#                 containing the new config params and properties
#
#         Returns:
#             (ControllerServiceEntity)
#
#     update_process_group(pg, update, refresh=True)
#         Updates a given Process Group.
#
#         Args:
#             pg (ProcessGroupEntity): The Process Group to
#               target for update
#             update (dict): key:value pairs to update
#             refresh (bool): Whether to refresh the Process Group before
#               applying the update
#
#         Returns:
#             (ProcessGroupEntity): The updated ProcessorEntity
#
#     update_processor(processor, update, refresh=True)
#         Updates configuration parameters for a given Processor.
#
#         An example update would be:
#         nifi.ProcessorConfigDTO(scheduling_period='3s')
#
#         Args:
#             processor (ProcessorEntity): The Processor to target for update
#             update (ProcessorConfigDTO): The new configuration parameters
#             refresh (bool): Whether to refresh the Processor object state
#               before applying the update
#
#         Returns:
#             (ProcessorEntity): The updated ProcessorEntity
#
#     update_variable_registry(process_group, update, refresh=True)
#         Updates one or more key:value pairs in the variable registry
#
#         Args:
#             process_group (ProcessGroupEntity): The Process Group which has the
#             Variable Registry to be updated
#             update (list[tuple]): The variables to write to the registry
#             refresh (bool): Whether to refresh the object revision before updating
#
#         Returns:
#             (VariableRegistryEntity): The created or updated Variable Registry
#             Entries
#
# DATA
#     __all__ = ['get_root_pg_id', 'recurse_flow', 'get_flow', 'get_process_...
#
# FILE
#     c:\users\ilia\appdata\roaming\python\python313\site-packages\nipyapi\canvas.py

# %% [markdown]
# #### 8. Автоматическое построение простого потока и его запуск

# %%
from nipyapi import canvas, config, nifi
from random import randrange

# 1. Настройка подключения
config.nifi_config.host = 'http://10.129.0.54:8080/nifi-api' 

# 2. Случайные координаты на canvas
location = (randrange(0, 4000), randrange(0, 4000))

# 3. Конфигурации процессоров
processor_GenFlowFile_config = {
    "properties": {
        "generate-ff-custom-text": "Hello World from Big Data School"
    },
    "schedulingPeriod": "10 sec",
    "schedulingStrategy": "TIMER_DRIVEN"
}

processor_PutFile_config = {
    "properties": {
        "Directory": "/home/ubuntu/test_pg",
        "Conflict Resolution Strategy": "replace",
        "Maximum File Count": "100"
    },
    "autoTerminatedRelationships": ["failure", "success"]
}

# 4. Получение root PG
root_pg_id = canvas.get_root_pg_id()
root_pg = canvas.get_process_group(root_pg_id, identifier_type='id')

# 5. Создание новой PG
new_pg = canvas.create_process_group(
    parent_pg=root_pg,
    new_pg_name='Test_process_group',
    location=location,
    comment='Demo group'
)
print(f"Создана процессная группа: {new_pg.id}")

# 6. Получение типов процессоров
gen_type = canvas.get_processor_type('org.apache.nifi.processors.standard.GenerateFlowFile', identifier_type='name')
put_type = canvas.get_processor_type('org.apache.nifi.processors.standard.PutFile', identifier_type='name')

# 7. Создание процессоров
p1 = canvas.create_processor(parent_pg=new_pg, processor=gen_type, location=(200, 200), config=processor_GenFlowFile_config)
p2 = canvas.create_processor(parent_pg=new_pg, processor=put_type, location=(200, 400), config=processor_PutFile_config)

# 8. Соединение процессоров
canvas.create_connection(p1, p2, relationships=['success'])
print("Процессоры соединены.")

# 9. Запуск PG
canvas.schedule_process_group(new_pg.id, scheduled=True)
print("Процессная группа запущена.")
# Out:
# Создана процессная группа: 3e1d8af0-0199-1000-5863-0790af5cef79
# Процессоры соединены.
# Процессная группа запущена.

# %%
from nipyapi import canvas, config

config.nifi_config.host = 'http://10.129.0.254:8443/nifi-api' 

pg_id = canvas.get_root_pg_id()
pg = canvas.get_process_group(pg_id, identifier_type='id')
print(pg.id, pg.component.name)
# Out:
# 018380c4-0199-1000-566f-3c43fff5b0a3 NiFi Flow

# %% [markdown]
# #### 9. Координаты расположения существующих объектов на канве

# %%
from nipyapi import canvas, config

# Настройка подключения к NiFi API
config.nifi_config.host = 'https://10.129.0.84:8443/nifi-api'

# Получение ID корневой группы процессов
root_id = canvas.get_root_pg_id()

# Получение всех процессоров в корневой группе процессов
processors = canvas.list_all_processors(root_id)

# Вывод имен и расположения всех процессоров
for processor in processors:
    name = processor.component.name
    position = processor.component.position
    print(f"Processor Name: {name}, Location: (x: {position.x}, y: {position.y})")
# Out:
# Processor Name: UpdateAttribute, Location: (x: 3112.6260513529605, y: 1794.5897424961859)
# Processor Name: AttributesToJSON, Location: (x: 1008.0, y: 392.0)
# Processor Name: ForkEnrichment, Location: (x: 1478.690983221707, y: 859.1398666752482)
# Processor Name: GenerateFlowFile, Location: (x: -184.0, y: -96.0)
# Processor Name: GenerateFlowFile, Location: (x: 200.0, y: 200.0)
# Processor Name: QueryDatabaseTableRecord, Location: (x: 424.0, y: 200.0)
# Processor Name: LogAttribute, Location: (x: 1656.0, y: 776.0)
# Processor Name: EvaluateJsonPath, Location: (x: -248.0, y: 424.0)
# Processor Name: SplitToJsons, Location: (x: 384.0, y: 392.0)
# Processor Name: PutFile, Location: (x: 2000.0, y: 2200.0)
# Processor Name: JoltTransformJSON, Location: (x: -184.0, y: 368.0)
# Processor Name: UpdateAttribute, Location: (x: 408.0, y: 248.0)
# Processor Name: GenerateFlowFile, Location: (x: 200.0, y: 200.0)
# Processor Name: HandleHttpResponse, Location: (x: 968.0, y: -160.0)
# Processor Name: GenerateFlowFile, Location: (x: 1480.0, y: 624.0)
# Processor Name: FlattenJson, Location: (x: 4048.6260513529605, y: 1410.5897424961859)
# Processor Name: ExecuteSQL, Location: (x: 1720.9999946420064, y: 381.00000267545204)
# Processor Name: UpdateAttribute, Location: (x: 2368.6260513529605, y: 1994.5897424961859)
# Processor Name: PutFile, Location: (x: 408.0, y: 488.0)
# Processor Name: RouteOnAttribute, Location: (x: 2040.0, y: 64.0)
# Processor Name: UpdateAttribute_Day+1, Location: (x: 3480.0, y: 648.0)
# Processor Name: JoltTransformJSON, Location: (x: 4048.0, y: 1208.0)
# Processor Name: PutDatabaseRecord, Location: (x: 384.0, y: 1352.0)
# Processor Name: GenerateFlowFile, Location: (x: -936.0, y: 112.0)
# Processor Name: ConsumeKafka, Location: (x: -40.0, y: -152.0)
# Processor Name: ConvertRecord, Location: (x: 3440.6260513529605, y: 2234.589742496186)
# Processor Name: CountText, Location: (x: 1008.0, y: 248.0)
# Processor Name: ExecuteSQL, Location: (x: 1720.9999946420064, y: 381.00000267545204)
# Processor Name: QueryDatabaseTableRecord, Location: (x: 384.0, y: 656.0)
# Processor Name: Write to '/processed2', Location: (x: 2664.0, y: 824.0)
# Processor Name: Check if Needs Reporting, Location: (x: 2664.0, y: 408.0)
# Processor Name: EvaluateJsonPath, Location: (x: 4056.0, y: 840.0)
# Processor Name: ExecuteSQL, Location: (x: -240.0, y: 1352.0)
# Processor Name: RouteOnAttribute, Location: (x: 2040.0, y: 64.0)
# Processor Name: RouteOnAttribute, Location: (x: 2848.0, y: 424.0)
# Processor Name: Add process_timestamp, Location: (x: 1008.0, y: 192.0)
# Processor Name: MergeRecord, Location: (x: 1720.0, y: 1496.0)
# Processor Name: InvokeHTTP, Location: (x: 4048.0, y: 984.0)
# Processor Name: Extract Key Values, Location: (x: 328.0, y: 624.0)
# Processor Name: JoinEnrichment, Location: (x: 2368.0, y: 1504.0)
# Processor Name: JoinEnrichment, Location: (x: 2368.0, y: 1504.0)
# Processor Name: LogAttribute, Location: (x: 1024.0, y: 648.0)
# Processor Name: GenerateFlowFile, Location: (x: -184.0, y: -96.0)
# Processor Name: PutFile, Location: (x: 200.0, y: 400.0)
# Processor Name: GenerateFlowFile, Location: (x: 4056.0, y: 432.0)
# Processor Name: SplitRecord, Location: (x: 3112.6260513529605, y: 1178.5897424961859)
# Processor Name: EvaluateJsonPath, Location: (x: 4056.0, y: 840.0)
# Processor Name: LogAttribute, Location: (x: 312.0, y: 1000.0)
# Processor Name: UpdateRecord, Location: (x: 4048.6260513529605, y: 1618.5897424961859)
# Processor Name: InvokeHTTP, Location: (x: 1416.0, y: 64.0)
# Processor Name: LookupRecord, Location: (x: 1024.0, y: 392.0)
# Processor Name: GenerateFlowFile, Location: (x: 1480.0, y: 624.0)
# Processor Name: Write to '/processed', Location: (x: 1008.0, y: 808.0)
# Processor Name: ConvertRecord, Location: (x: 4048.6260513529605, y: 2026.5897424961859)
# Processor Name: UpdateAttribute, Location: (x: -184.0, y: 136.0)
# Processor Name: UpdateAttribute_Day+1, Location: (x: 3480.0, y: 648.0)
# Processor Name: MergeRecord, Location: (x: 1720.0, y: 1496.0)
# Processor Name: JoltTransformJSON, Location: (x: 2768.0, y: 2240.0)
# Processor Name: QueryRecord, Location: (x: 1024.0, y: 168.0)
# Processor Name: PutDatabaseRecord, Location: (x: -888.0, y: 840.0)
# Processor Name: LogAttribute, Location: (x: 1024.0, y: 648.0)
# Processor Name: RouteOnContent, Location: (x: 3112.6260513529605, y: 1378.5897424961859)
# Processor Name: UpdateAttribute, Location: (x: 2368.6260513529605, y: 1994.5897424961859)
# Processor Name: LogAttribute, Location: (x: 1651.0000158053645, y: 1144.9999570947555)
# Processor Name: UpdateAttribute, Location: (x: -184.0, y: 136.0)
# Processor Name: JoinEnrichment, Location: (x: 2144.0, y: 856.0)
# Processor Name: PutDatabaseRecord, Location: (x: 1720.9999946420064, y: 165.00000267545204)
# Processor Name: GenerateFlowFile, Location: (x: 2000.0, y: 2000.0)
# Processor Name: QueryDatabaseTableRecord, Location: (x: 384.0, y: 656.0)
# Processor Name: Get Table Name, Location: (x: 422.0000415345295, y: 466.9999815120939)
# Processor Name: PutFile, Location: (x: 200.0, y: 400.0)
# Processor Name: ConvertRecord, Location: (x: 3440.6260513529605, y: 2234.589742496186)
# Processor Name: UpdateAttribute, Location: (x: -136.0, y: -16.0)
# Processor Name: EvaluateJsonPath, Location: (x: 3112.6260513529605, y: 1586.5897424961859)
# Processor Name: GenerateFlowFile, Location: (x: 408.0, y: 32.0)
# Processor Name: AttributesToCSV, Location: (x: 1008.0, y: 488.0)
# Processor Name: PutFile, Location: (x: 2000.0, y: 2200.0)
# Processor Name: UpdateAttribute, Location: (x: 968.0, y: -368.0)
# Processor Name: GenerateFlowFile, Location: (x: -40.0, y: -664.0)
# Processor Name: 1 Line per FlowFile, Location: (x: 328.0, y: 392.0)
# Processor Name: PutFile, Location: (x: -936.0, y: 576.0)
# Processor Name: GenerateFlowFile, Location: (x: 2000.0, y: 2000.0)
# Processor Name: PutFile, Location: (x: -136.0, y: 216.0)
# Processor Name: MergeContent, Location: (x: 360.0, y: 152.0)
# Processor Name: UpdateAttribute, Location: (x: 4048.6260513529605, y: 1826.5897424961859)
# Processor Name: ReplaceText, Location: (x: 1008.0, y: 32.0)
# Processor Name: GetFile, Location: (x: 384.9999946420064, y: 165.00000267545204)
# Processor Name: UpdateAttribute, Location: (x: 280.0, y: -224.0)
# Processor Name: GenerateFlowFile, Location: (x: 360.0, y: -40.0)
# Processor Name: UpdateAttribute, Location: (x: 3112.6260513529605, y: 1794.5897424961859)
# Processor Name: PutFile, Location: (x: 2000.0, y: 2200.0)
# Processor Name: MergeContent, Location: (x: -1424.0, y: 656.0)
# Processor Name: HandleHttpRequest, Location: (x: 360.0, y: -368.0)
# Processor Name: UpdateAttribute, Location: (x: 968.0, y: -368.0)
# Processor Name: GenerateFlowFile, Location: (x: 2000.0, y: 2000.0)
# Processor Name: MergeContent, Location: (x: 360.0, y: 152.0)
# Processor Name: HandleHttpRequest, Location: (x: 360.0, y: -368.0)
# Processor Name: PutFile, Location: (x: 200.0, y: 400.0)
# Processor Name: Add process_time, Write as JSON, Location: (x: 2664.0, y: 624.0)
# Processor Name: FlattenJson, Location: (x: 4048.6260513529605, y: 1410.5897424961859)
# Processor Name: JoltTransformJSON, Location: (x: 1608.0, y: 488.0)
# Processor Name: JoltTransformJSON, Location: (x: 384.0, y: 1136.0)
# Processor Name: PutDatabaseRecord, Location: (x: 384.0, y: 840.0)
# Processor Name: JoltTransformJSON, Location: (x: 4048.0, y: 1208.0)
# Processor Name: UnpackContent, Location: (x: 784.0, y: 64.0)
# Processor Name: CaptureChangeMySQL, Location: (x: 1008.0, y: 64.0)
# Processor Name: ExecuteScript, Location: (x: -560.0, y: -248.0)
# Processor Name: InvokeHTTP, Location: (x: 3112.6260513529605, y: 978.589742496186)
# Processor Name: StartFromAPI, Location: (x: 832.0, y: 288.0)
# Processor Name: PutDatabaseRecord, Location: (x: 1720.9999946420064, y: 165.00000267545204)
# Processor Name: JoltTransformJSON, Location: (x: 2768.0, y: 2240.0)
# Processor Name: LookupRecord, Location: (x: 1024.0, y: 392.0)
# Processor Name: SplitJson, Location: (x: 4056.0, y: 640.0)
# Processor Name: GenerateFlowFile, Location: (x: -136.0, y: -256.0)
# Processor Name: PublishKafka, Location: (x: -40.0, y: -408.0)
# Processor Name: SplitJson, Location: (x: 4056.0, y: 640.0)
# Processor Name: UpdateAttribute, Location: (x: 4048.6260513529605, y: 1826.5897424961859)
# Processor Name: Re-Merge, Location: (x: 1008.0, y: 600.0)
# Processor Name: PutFile, Location: (x: 2000.0, y: 2200.0)
# Processor Name: QueryRecord, Location: (x: 1024.0, y: 168.0)
# Processor Name: UpdateRecord, Location: (x: 4048.6260513529605, y: 1618.5897424961859)
# Processor Name: InvokeHTTP, Location: (x: 4048.0, y: 984.0)
# Processor Name: RouteOnContent, Location: (x: 3112.6260513529605, y: 1378.5897424961859)
# Processor Name: JoinEnrichment, Location: (x: 2144.0, y: 856.0)
# Processor Name: JoltTransformJSON, Location: (x: 416.0, y: 720.0)
# Processor Name: SplitToJsons, Location: (x: 384.0, y: 392.0)
# Processor Name: PutFile, Location: (x: 1104.6260513529603, y: 1498.5897424961859)
# Processor Name: GenerateFlowFile, Location: (x: 2000.0, y: 2000.0)
# Processor Name: MergeContent, Location: (x: -936.0, y: 352.0)
# Processor Name: RouteOnAttribute, Location: (x: 2848.0, y: 424.0)
# Processor Name: InvokeHTTP, Location: (x: 1416.0, y: 64.0)
# Processor Name: RouteOnAttribute, Location: (x: 1006.0000415345295, y: 282.9999815120939)
# Processor Name: GenerateFlowFile, Location: (x: 424.0, y: 80.0)
# Processor Name: FetchFile, Location: (x: 2664.0, y: 192.0)
# Processor Name: MergeRecord, Location: (x: 4048.6260513529605, y: 2234.589742496186)
# Processor Name: RouteToDate, Location: (x: 3480.0, y: 424.0)
# Processor Name: JoltTransformJSON, Location: (x: -184.0, y: 368.0)
# Processor Name: GenerateFlowFile, Location: (x: -560.0, y: -504.0)
# Processor Name: ListFile, Location: (x: 328.0, y: -8.0)
# Processor Name: UpdateAttribute, Location: (x: 424.0, y: 336.0)
# Processor Name: ForkEnrichment, Location: (x: 1478.690983221707, y: 859.1398666752482)
# Processor Name: JoltTransformJSON, Location: (x: -888.0, y: 632.0)
# Processor Name: PutFile, Location: (x: 1104.6260513529603, y: 1498.5897424961859)
# Processor Name: GetFile, Location: (x: 384.9999946420064, y: 165.00000267545204)
# Processor Name: ListFile, Location: (x: 2664.0, y: -8.0)
# Processor Name: SplitRecord, Location: (x: 3112.6260513529605, y: 1178.5897424961859)
# Processor Name: RouteToDate, Location: (x: 3480.0, y: 424.0)
# Processor Name: MergeRecord, Location: (x: 4048.6260513529605, y: 2234.589742496186)
# Processor Name: GenerateFlowFile, Location: (x: 4056.0, y: 432.0)
# Processor Name: GenerateFlowFile, Location: (x: 200.0, y: 200.0)
# Processor Name: ConvertRecord, Location: (x: -1424.0, y: 432.0)
# Processor Name: Schema=users & Statement Type, Location: (x: 416.0, y: 952.0)
# Processor Name: EvaluateJsonPath, Location: (x: 3112.6260513529605, y: 1586.5897424961859)
# Processor Name: ExecuteSQLRecord, Location: (x: -248.0, y: 208.0)
# Processor Name: UpdateAttribute, Location: (x: -240.0, y: 1136.0)
# Processor Name: GenerateFlowFile, Location: (x: -1424.0, y: 216.0)
# Processor Name: PutDatabaseRecord, Location: (x: 1006.0000415345295, y: 1138.9999815120939)
# Processor Name: InvokeHTTP, Location: (x: 3112.6260513529605, y: 978.589742496186)
# Processor Name: HandleHttpResponse, Location: (x: 1576.0, y: -368.0)
# Processor Name: EnforceOrder, Location: (x: 1006.0000415345295, y: 962.9999815120938)
# Processor Name: PutFile, Location: (x: 200.0, y: 400.0)
# Processor Name: Schema=query & SmtTyp=SQL, Location: (x: 1008.0, y: 704.0)
# Processor Name: UpdateAttribute, Location: (x: -1424.0, y: 864.0)
# Processor Name: ConvertRecord, Location: (x: 4048.6260513529605, y: 2026.5897424961859)
# Processor Name: Check if Needs Reporting, Location: (x: 1008.0, y: -8.0)
# Processor Name: GenerateFlowFile, Location: (x: 200.0, y: 200.0)
# Processor Name: GenerateFlowFile, Location: (x: 360.0, y: -40.0)
# Processor Name: UnpackContent, Location: (x: 784.0, y: 64.0)
# Processor Name: FetchFile, Location: (x: 328.0, y: 192.0)
# Processor Name: UpdateRecord, Location: (x: -248.0, y: 632.0)
